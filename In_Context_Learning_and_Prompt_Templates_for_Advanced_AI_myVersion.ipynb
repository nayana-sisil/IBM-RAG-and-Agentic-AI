# %%
pip install -U "langchain[google-genai]"
# Out:
# Requirement already satisfied: langchain[google-genai] in /usr/local/lib/python3.12/dist-packages (1.2.14)
# Collecting langchain[google-genai]
#   Downloading langchain-1.2.15-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.2.10 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (1.2.23)
# Collecting langgraph<1.2.0,>=1.1.5 (from langchain[google-genai])
#   Downloading langgraph-1.1.6-py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain[google-genai]) (2.12.3)
# Collecting langchain-google-genai (from langchain[google-genai])
#   Downloading langchain_google_genai-4.2.1-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (1.33)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.7.23)
# Requirement already satisfied: packaging>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (26.0)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.14.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (4.0.1)
# Collecting langgraph-prebuilt<1.1.0,>=1.0.9 (from langgraph<1.2.0,>=1.1.5->langchain[google-genai])
#   Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (0.3.12)
# Requirement already satisfied: xxhash>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (3.6.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain[google-genai]) (0.4.2)
# Collecting filetype<2.0.0,>=1.2.0 (from langchain-google-genai->langchain[google-genai])
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: google-genai<2.0.0,>=1.56.0 in /usr/local/lib/python3.12/dist-packages (from langchain-google-genai->langchain[google-genai]) (1.68.0)
# Requirement already satisfied: anyio<5.0.0,>=4.8.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (4.13.0)
# Requirement already satisfied: google-auth<3.0.0,>=2.47.0 in /usr/local/lib/python3.12/dist-packages (from google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (2.47.0)
# Requirement already satisfied: httpx<1.0.0,>=0.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (0.28.1)
# Requirement already satisfied: requests<3.0.0,>=2.28.1 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (2.32.4)
# Requirement already satisfied: websockets<17.0,>=13.0.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (15.0.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (1.9.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (1.3.1)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (3.1.1)
# Requirement already satisfied: ormsgpack>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (1.12.2)
# Requirement already satisfied: orjson>=3.11.5 in /usr/local/lib/python3.12/dist-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.5->langchain[google-genai]) (3.11.8)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.2.10->langchain[google-genai]) (0.25.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5.0.0,>=4.8.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (3.11)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.12/dist-packages (from google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (4.9.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1.0.0,>=0.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (0.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.28.1->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (2.5.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.6.1 in /usr/local/lib/python3.12/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3.0.0,>=2.47.0->google-auth[requests]<3.0.0,>=2.47.0->google-genai<2.0.0,>=1.56.0->langchain-google-genai->langchain[google-genai]) (0.6.3)
# Downloading langgraph-1.1.6-py3-none-any.whl (169 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.8/169.8 kB 7.9 MB/s eta 0:00:00
# Downloading langchain-1.2.15-py3-none-any.whl (112 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.7/112.7 kB 13.7 MB/s eta 0:00:00
# Downloading langchain_google_genai-4.2.1-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 kB 9.1 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading langgraph_prebuilt-1.0.9-py3-none-any.whl (35 kB)
# Installing collected packages: filetype, langchain-google-genai, langgraph-prebuilt, langgraph, langchain
#   Attempting uninstall: langgraph-prebuilt
#     Found existing installation: langgraph-prebuilt 1.0.8
#     Uninstalling langgraph-prebuilt-1.0.8:
#       Successfully uninstalled langgraph-prebuilt-1.0.8
#   Attempting uninstall: langgraph
#     Found existing installation: langgraph 1.1.4
#     Uninstalling langgraph-1.1.4:
#       Successfully uninstalled langgraph-1.1.4
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.14
#     Uninstalling langchain-1.2.14:
#       Successfully uninstalled langchain-1.2.14
# Successfully installed filetype-1.2.0 langchain-1.2.15 langchain-google-genai-4.2.1 langgraph-1.1.6 langgraph-prebuilt-1.0.9

# %%
import os
from langchain.chat_models import init_chat_model

# Set API key
os.environ["GOOGLE_API_KEY"] = "AIzaSyC48mOBTqOA6pEVVmgTNZlf-7-WqZkkwOo"

# Initialize model
model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# Invoke model
response = model.invoke("Why do parrots talk?")

print(response.content)
# Out:
# Parrots talk for a fascinating combination of reasons, primarily driven by their **intelligence, social nature, and a drive to communicate and bond.** It's not just mimicry; it's a complex behavior with evolutionary roots.
#
# Here's a breakdown of the main reasons why parrots talk:
#
# **1. Social Bonding and Communication:**
#
# *   **Flock Behavior:** In the wild, parrots live in large, complex social groups. Talking, or vocalizing, is crucial for maintaining these bonds. They use a variety of calls and sounds to:
#     *   **Identify each other:** Recognize individuals within the flock.
#     *   **Maintain contact:** Keep track of where others are, especially when foraging or flying.
#     *   **Signal danger:** Alert the flock to predators.
#     *   **Coordinate activities:** Communicate about food sources or other important information.
#     *   **Strengthen social ties:** Engage in mutual preening and vocal exchanges.
# *   **Mimicry as a Social Tool:** Their ability to mimic sounds, including human speech, is believed to be an extension of this social need. By imitating sounds in their environment, including those of their flock mates (or in captivity, their human "flock"), they can:
#     *   **Integrate into the group:** Become accepted and recognized by others.
#     *   **Gain attention:** Get noticed and interact with their companions.
#     *   **Learn about their environment:** Pick up on sounds that might be important for survival or foraging.
#
# **2. Intelligence and Cognitive Abilities:**
#
# *   **Advanced Brains:** Parrots have remarkably large and complex brains for their size. This allows for sophisticated cognitive processes, including:
#     *   **Learning and Memory:** They can learn and remember a wide range of sounds and associate them with specific contexts or rewards.
#     *   **Problem-Solving:** Some studies suggest parrots can understand the meaning of words and use them in novel ways, demonstrating a level of comprehension beyond simple repetition.
#     *   **Understanding Cause and Effect:** They might learn that making a certain sound can lead to a desired outcome (e.g., getting a treat, attention).
#
# **3. Desire for Attention and Interaction:**
#
# *   **Curiosity and Engagement:** Parrots are naturally curious and enjoy engaging with their environment and companions. Talking is a primary way for them to do this.
# *   **Seeking Reinforcement:** When a parrot says a word or phrase and receives positive reinforcement (praise, a treat, interaction), they are more likely to repeat that behavior. This is a powerful motivator for them to "talk."
# *   **Boredom and Stimulation:** In captivity, if a parrot is bored or not receiving enough mental stimulation, talking can become a way to entertain themselves and get attention.
#
# **4. Individual Personality and Variation:**
#
# *   **Not all parrots talk equally:** Just like humans, some parrots are more inclined to talk than others. Factors like species, individual personality, and the environment they are raised in play a significant role.
# *   **Some species are better mimics:** Certain species, like African Greys, Amazon parrots, and Budgerigars, are renowned for their talking abilities.
#
# **In summary, parrots talk because:**
#
# *   **It's ingrained in their evolutionary need to communicate and bond within social groups.**
# *   **They possess the intelligence and cognitive abilities to learn and process complex vocalizations.**
# *   **They are driven by a desire for attention, interaction, and reinforcement from their companions.**
#
# While they might not "understand" language in the same way humans do, their ability to mimic, associate sounds with contexts, and use vocalizations to achieve social goals is truly remarkable and a testament to their intelligence.

# %%
from langchain_core.prompts import PromptTemplate, ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough, RunnableSequence
from langchain_core.messages import HumanMessage, SystemMessage

# %% [markdown]
# # function for runnning locally

# %%
def llm_model(prompt_txt, temperature=0.5):

    os.environ["GOOGLE_API_KEY"] = "AIzaSyC48mOBTqOA6pEVVmgTNZlf-7-WqZkkwOo"

    model = init_chat_model(
        "google_genai:gemini-2.5-flash-lite",
        temperature=temperature
    )

    response = model.invoke(prompt_txt)

    return response.content

# %% [markdown]
# # Prompt engineering
#
# ##Basic prompt

# %%
prompt = "The wind is "

llm_model(prompt)
# Out:
# "The wind is **blowing**.\n\nThat's the most common and natural way to complete that sentence.\n\nHowever, you could also say:\n\n*   The wind is **strong**.\n*   The wind is **gentle**.\n*   The wind is **cold**.\n*   The wind is **warm**.\n*   The wind is **howling**.\n*   The wind is **whispering**.\n*   The wind is **changing direction**.\n*   The wind is **picking up**.\n*   The wind is **dying down**.\n\nTo give you a more specific answer, I need more context! What are you trying to describe about the wind?"

# %% [markdown]
# ## Zero-shot prompt

# %%
prompt = """Classify the following statement as true or false:
            'The Eiffel Tower is located in Berlin.'

            Answer:
"""
response = llm_model(prompt)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Classify the following statement as true or false:
#             'The Eiffel Tower is located in Berlin.'
#
#             Answer:
#
#
# response : False

# %% [markdown]
# ##  One-shot prompt

# %%
prompt = """Here is an example of translating a sentence from English to French:

            English: “How is the weather today?”
            French: “Comment est le temps aujourd'hui?”

            Now, translate the following sentence from English to French:

            English: “Where is the nearest supermarket?”

"""
response = llm_model(prompt, 0)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Here is an example of translating a sentence from English to French:
#
#             English: “How is the weather today?”
#             French: “Comment est le temps aujourd'hui?”
#
#             Now, translate the following sentence from English to French:
#
#             English: “Where is the nearest supermarket?”
#
#
#
# response : French: “Où est le supermarché le plus proche?”

# %% [markdown]
# ##  Few-shot prompt

# %%
prompt = """Here are few examples of classifying emotions in statements:

            Statement: 'I just won my first marathon!'
            Emotion: Joy

            Statement: 'I can't believe I lost my keys again.'
            Emotion: Frustration

            Statement: 'My best friend is moving to another country.'
            Emotion: Sadness

            Now, classify the emotion in the following statement:
            Statement: 'That movie was so scary I had to cover my eyes.’


"""
response = llm_model(prompt)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Here are few examples of classifying emotions in statements:
#
#             Statement: 'I just won my first marathon!'
#             Emotion: Joy
#
#             Statement: 'I can't believe I lost my keys again.'
#             Emotion: Frustration
#
#             Statement: 'My best friend is moving to another country.'
#             Emotion: Sadness
#
#             Now, classify the emotion in the following statement:
#             Statement: 'That movie was so scary I had to cover my eyes.’
#
#
#
#
# response : Emotion: Fear

# %% [markdown]
# ## Chain-of-thought (CoT) prompt

# %%
prompt = """Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples.
            How many apples are there now?’

            Break down each step of your calculation

"""
response = llm_model(prompt)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: Consider the problem: 'A store had 22 apples. They sold 15 apples today and got a new delivery of 8 apples.
#             How many apples are there now?’
#
#             Break down each step of your calculation
#
#
#
# response : Here's a step-by-step breakdown of the calculation to solve the apple problem:
#
# **1. Understand the Starting Point:**
#
# *   The store began with a certain number of apples.
# *   **Calculation:** The initial number of apples is 22.
#
# **2. Account for Apples Sold:**
#
# *   The store sold some apples, which means the number of apples decreased.
# *   **Calculation:** We need to subtract the number of apples sold from the initial amount.
#     *   22 (initial apples) - 15 (apples sold) = 7 apples
#
# **3. Account for the New Delivery:**
#
# *   The store received more apples, which means the number of apples increased.
# *   **Calculation:** We need to add the number of apples from the new delivery to the current amount.
#     *   7 (apples after selling) + 8 (new delivery) = 15 apples
#
# **4. Final Answer:**
#
# *   The total number of apples the store has now is the result of the previous steps.
# *   **Calculation:** The final count is 15 apples.
#
# **Summary of Calculations:**
#
# *   **Step 1 (Starting):** 22 apples
# *   **Step 2 (After Selling):** 22 - 15 = 7 apples
# *   **Step 3 (After Delivery):** 7 + 8 = 15 apples
#
# **Therefore, there are now 15 apples.**

# %% [markdown]
# ## Self-consistency

# %%
prompt = """When I was 6, my sister was half of my age. Now I am 70, what age is my sister?

            Provide three independent calculations and explanations, then determine the most consistent result.

"""
response = llm_model(prompt)
print(f"prompt: {prompt}\n")
print(f"response : {response}\n")
# Out:
# prompt: When I was 6, my sister was half of my age. Now I am 70, what age is my sister?
#
#             Provide three independent calculations and explanations, then determine the most consistent result.
#
#
#
# response : Here are three independent calculations to determine your sister's age, followed by a determination of the most consistent result:
#
# ## Calculation 1: Age Difference
#
# *   **Explanation:** The core of this problem lies in the age difference between you and your sister. This difference remains constant throughout your lives.
# *   **Calculation:**
#     *   When you were 6, your sister was half your age, so she was 6 / 2 = 3 years old.
#     *   The age difference between you and your sister is 6 - 3 = 3 years.
#     *   Since you are now 70, your sister will be 3 years younger than you.
#     *   Therefore, your sister is 70 - 3 = **67 years old**.
#
# ## Calculation 2: Ratio of Ages (and its implication)
#
# *   **Explanation:** This method focuses on the initial ratio of your ages and how that ratio *changes* over time, which is crucial for understanding why a simple ratio calculation at the current age wouldn't work.
# *   **Calculation:**
#     *   When you were 6, your sister was 3. Your sister's age was 3/6 = 1/2 of your age.
#     *   This means your sister is always 3 years younger than you (as established in Calculation 1).
#     *   If you were to simply apply the 1/2 ratio now, you would get 70 / 2 = 35, which is incorrect because the ratio of ages is not constant.
#     *   The consistent factor is the **age difference**.
#     *   Therefore, your sister's age is your current age minus the constant age difference: 70 - 3 = **67 years old**.
#
# ## Calculation 3: Tracking Ages Through Time
#
# *   **Explanation:** This method involves setting up a clear relationship between your ages and then applying it to your current age.
# *   **Calculation:**
#     *   Let your current age be 'Y' and your sister's current age be 'S'.
#     *   We know that when you were 6, your sister was 3. This means your sister is always 3 years younger than you.
#     *   So, the relationship between your ages is: Y = S + 3, or S = Y - 3.
#     *   You are now 70 (Y = 70).
#     *   Using the relationship S = Y - 3:
#     *   S = 70 - 3 = **67 years old**.
#
# ## Most Consistent Result
#
# All three independent calculations lead to the same conclusion. The most consistent and accurate result is that your sister is **67 years old**.
#
# The key to solving this puzzle is understanding that the *age difference* between siblings remains constant, while the *ratio* of their ages changes over time.

# %%
# Introduction to LangChain

# %% [markdown]
# # Introduction to LangChain

# %% [markdown]
# Prompt template
# Prompt templates are a key concept in LangChain. They help translate user input and parameters into instructions for a language model. These templates can be used to guide a model's response, helping it understand the context and generate relevant and coherent language-based outputs.
#
# A prompt template acts as a reusable structure for generating prompts with dynamic values. It allows you to define a consistent format while leaving placeholders for variables that change with each use case. This approach makes prompting more systematic and maintainable, especially when working with complex applications.
#
# Modern LangChain (as of 2025) offers two main approaches to working with templates:
#
# The traditional LLMChain approach
# The newer LangChain Expression Language (LCEL) pattern using the pipe operator | for more flexible composition
# LCEL has become the recommended pattern for building LangChain applications as it offers better composability, clearer visualization of data flow, and more flexibility when constructing complex chains.
#
# To use a prompt template with LCEL, you typically follow these steps:
#
# Define your template with variables in curly braces {}
# Create a PromptTemplate instance
# Build a chain using the pipe operator | to connect components
# Invoke the chain with your input values
# Let's initialize an LLM first, then demonstrate this approach. In this section, we will use the model meta-llama/llama-3-3-70b-instruct:

# %%
os.environ["GOOGLE_API_KEY"] = "AIzaSyC48mOBTqOA6pEVVmgTNZlf-7-WqZkkwOo"


model = init_chat_model("google_genai:gemini-2.5-flash-lite")

# %%
template = """Tell me a {adjective} joke about {content}.
"""

prompt = PromptTemplate.from_template(template)
prompt
# Out:
# PromptTemplate(input_variables=['adjective', 'content'], input_types={}, partial_variables={}, template='Tell me a {adjective} joke about {content}.\n')

# %%
prompt.format(adjective="funny", content="chickens")
# Out:
# 'Tell me a funny joke about chickens.\n'

# %%
from langchain_core.runnables import RunnableLambda

# Define a function to ensure proper formatting
def format_prompt(variables):
    return prompt.format(**variables)

# %%
# Create the chain with explicit formatting
joke_chain = (
    RunnableLambda(format_prompt)
    | model
    | StrOutputParser()
)

# Run the chain
response = joke_chain.invoke({"adjective": "funny", "content": "chickens"})
print(response)
# Out:
# Why did the chicken cross the road?
#
# To get to the other *side*!

# %%
response = joke_chain.invoke({"adjective": "sad", "content": "fish"})
print(response)
# Out:
# Why did the fish blush?
#
# Because it saw the ocean's bottom.

# %% [markdown]
# # Text summarization

# %%
content = """
    The rapid advancement of technology in the 21st century has transformed various industries, including healthcare, education, and transportation.
    Innovations such as artificial intelligence, machine learning, and the Internet of Things have revolutionized how we approach everyday tasks and complex problems.
    For instance, AI-powered diagnostic tools are improving the accuracy and speed of medical diagnoses, while smart transportation systems are making cities more efficient and reducing traffic congestion.
    Moreover, online learning platforms are making education more accessible to people around the world, breaking down geographical and financial barriers.
    These technological developments are not only enhancing productivity but also contributing to a more interconnected and informed society.
"""

template = """Summarize the {content} in one sentence.
"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
summarize_chain = (
    RunnableLambda(format_prompt)
    | model
    | StrOutputParser()
)

# Run the chain
summary = summarize_chain.invoke({"content": content})
print(summary)
# Out:
# Technological advancements like AI, machine learning, and IoT are revolutionizing healthcare, education, and transportation, leading to increased efficiency, accessibility, and a more interconnected society.

# %% [markdown]
# # Question answering

# %%
content = """
    The solar system consists of the Sun, eight planets, their moons, dwarf planets, and smaller objects like asteroids and comets.
    The inner planets—Mercury, Venus, Earth, and Mars—are rocky and solid.
    The outer planets—Jupiter, Saturn, Uranus, and Neptune—are much larger and gaseous.
"""

question = "Which planets in the solar system are rocky and solid?"

template = """
    Answer the {question} based on the {content}.
    Respond "Unsure about answer" if not sure about the answer.

    Answer:

"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
qa_chain = (
    RunnableLambda(format_prompt)
    | model
    | StrOutputParser()
)

# Run the chain
answer = qa_chain.invoke({"question": question, "content": content})
print(answer)
# Out:
# The planets in the solar system that are rocky and solid are Mercury, Venus, Earth, and Mars.

# %% [markdown]
# # Text classification

# %%
text = """
    The concert last night was an exhilarating experience with outstanding performances by all artists.
"""

categories = "Entertainment, Food and Dining, Technology, Literature, Music."

template = """
    Classify the {text} into one of the {categories}.

    Category:

"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
classification_chain = (
    RunnableLambda(format_prompt)
    | model
    | StrOutputParser()
)

# Run the chain
category = classification_chain.invoke({"text": text, "categories": categories})
print(category)
# Out:
# Category: Music

# %% [markdown]
# # Code generation

# %%
description = """
    Retrieve the names and email addresses of all customers from the 'customers' table who have made a purchase in the last 30 days.
    The table 'purchases' contains a column 'purchase_date'
"""

template = """
    Generate an SQL query based on the {description}

    SQL Query:

"""
prompt = PromptTemplate.from_template(template)

# Create the LCEL chain
sql_generation_chain = (
    RunnableLambda(format_prompt)
    | model
    | StrOutputParser()
)

# Run the chain
sql_query = sql_generation_chain.invoke({"description": description})
print(sql_query)
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3046         try:
# -> 3047             response: GenerateContentResponse = self.client.models.generate_content(
#    3048                 **request,
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in generate_content(self, model, contents, config)
#    5863       i += 1
# -> 5864       response = self._generate_content(
#    5865           model=model, contents=contents, config=parsed_config
#
# /usr/local/lib/python3.12/dist-packages/google/genai/models.py in _generate_content(self, model, contents, config)
#    4525
# -> 4526     response = self._api_client.request(
#    4527         'post', path, request_dict, http_options
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in request(self, http_method, path, request_dict, http_options)
#    1401     )
# -> 1402     response = self._request(http_request, http_options, stream=False)
#    1403     response_body = (
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request(self, http_request, http_options, stream)
#    1235         retry = tenacity.Retrying(**retry_kwargs)
# -> 1236         return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
#    1237
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     469         while True:
# --> 470             do = self.iter(retry_state=retry_state)
#     471             if isinstance(do, DoAttempt):
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in iter(self, retry_state)
#     370         for action in self.iter_state.actions:
# --> 371             result = action(retry_state)
#     372         return result
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in exc_check(rs)
#     412                 if self.reraise:
# --> 413                     raise retry_exc.reraise()
#     414                 raise retry_exc from fut.exception()
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in reraise(self)
#     183         if self.last_attempt.failed:
# --> 184             raise self.last_attempt.result()
#     185         raise self
#
# /usr/lib/python3.12/concurrent/futures/_base.py in result(self, timeout)
#     448                 elif self._state == FINISHED:
# --> 449                     return self.__get_result()
#     450
#
# /usr/lib/python3.12/concurrent/futures/_base.py in __get_result(self)
#     400             try:
# --> 401                 raise self._exception
#     402             finally:
#
# /usr/local/lib/python3.12/dist-packages/tenacity/__init__.py in __call__(self, fn, *args, **kwargs)
#     472                 try:
# --> 473                     result = fn(*args, **kwargs)
#     474                 except BaseException:  # noqa: B902
#
# /usr/local/lib/python3.12/dist-packages/google/genai/_api_client.py in _request_once(self, http_request, stream)
#    1214       )
# -> 1215       errors.APIError.raise_for_response(response)
#    1216       return HttpResponse(
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_for_response(cls, response)
#     133
# --> 134     cls.raise_error(response.status_code, response_json, response)
#     135
#
# /usr/local/lib/python3.12/dist-packages/google/genai/errors.py in raise_error(cls, status_code, response_json, response)
#     158     if 400 <= status_code < 500:
# --> 159       raise ClientError(status_code, response_json, response)
#     160     elif 500 <= status_code < 600:
#
# ClientError: 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 56.582791057s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '56s'}]}}
#
# The above exception was the direct cause of the following exception:
#
# ChatGoogleGenerativeAIError               Traceback (most recent call last)
# /tmp/ipykernel_3449/966794031.py in <cell line: 0>()
#      20
#      21 # Run the chain
# ---> 22 sql_query = sql_generation_chain.invoke({"description": description})
#      23 print(sql_query)
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/runnables/base.py in invoke(self, input, config, **kwargs)
#    3155                         input_ = context.run(step.invoke, input_, config, **kwargs)
#    3156                     else:
# -> 3157                         input_ = context.run(step.invoke, input_, config)
#    3158         # finish the root run
#    3159         except BaseException as e:
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in invoke(self, input, config, code_execution, stop, **kwargs)
#    2533                 raise ValueError(msg)
#    2534
# -> 2535         return super().invoke(input, config, stop=stop, **kwargs)
#    2536
#    2537     def _get_ls_params(
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in invoke(self, input, config, stop, **kwargs)
#     452             cast(
#     453                 "ChatGeneration",
# --> 454                 self.generate_prompt(
#     455                     [self._convert_input(input)],
#     456                     stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate_prompt(self, prompts, stop, callbacks, **kwargs)
#    1183     ) -> LLMResult:
#    1184         prompt_messages = [p.to_messages() for p in prompts]
# -> 1185         return self.generate(prompt_messages, stop=stop, callbacks=callbacks, **kwargs)
#    1186
#    1187     @override
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in generate(self, messages, stop, callbacks, tags, metadata, run_name, run_id, **kwargs)
#     993             try:
#     994                 results.append(
# --> 995                     self._generate_with_cache(
#     996                         m,
#     997                         stop=stop,
#
# /usr/local/lib/python3.12/dist-packages/langchain_core/language_models/chat_models.py in _generate_with_cache(self, messages, stop, run_manager, **kwargs)
#    1295             result = generate_from_stream(iter(chunks))
#    1296         elif inspect.signature(self._generate).parameters.get("run_manager"):
# -> 1297             result = self._generate(
#    1298                 messages, stop=stop, run_manager=run_manager, **kwargs
#    1299             )
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _generate(self, messages, stop, run_manager, tools, functions, safety_settings, tool_config, generation_config, cached_content, tool_choice, **kwargs)
#    3049             )
#    3050         except ClientError as e:
# -> 3051             _handle_client_error(e, request)
#    3052
#    3053         return _response_to_result(response)
#
# /usr/local/lib/python3.12/dist-packages/langchain_google_genai/chat_models.py in _handle_client_error(e, request)
#     143     model_name = request.get("model", "unknown")
#     144     msg = f"Error calling model '{model_name}' ({e.status}): {e}"
# --> 145     raise ChatGoogleGenerativeAIError(msg) from e
#     146
#     147
#
# ChatGoogleGenerativeAIError: Error calling model 'gemini-2.5-flash-lite' (RESOURCE_EXHAUSTED): 429 RESOURCE_EXHAUSTED. {'error': {'code': 429, 'message': 'You exceeded your current quota, please check your plan and billing details. For more information on this error, head to: https://ai.google.dev/gemini-api/docs/rate-limits. To monitor your current usage, head to: https://ai.dev/rate-limit. \n* Quota exceeded for metric: generativelanguage.googleapis.com/generate_content_free_tier_requests, limit: 20, model: gemini-2.5-flash-lite\nPlease retry in 56.582791057s.', 'status': 'RESOURCE_EXHAUSTED', 'details': [{'@type': 'type.googleapis.com/google.rpc.Help', 'links': [{'description': 'Learn more about Gemini API quotas', 'url': 'https://ai.google.dev/gemini-api/docs/rate-limits'}]}, {'@type': 'type.googleapis.com/google.rpc.QuotaFailure', 'violations': [{'quotaMetric': 'generativelanguage.googleapis.com/generate_content_free_tier_requests', 'quotaId': 'GenerateRequestsPerDayPerProjectPerModel-FreeTier', 'quotaDimensions': {'location': 'global', 'model': 'gemini-2.5-flash-lite'}, 'quotaValue': '20'}]}, {'@type': 'type.googleapis.com/google.rpc.RetryInfo', 'retryDelay': '56s'}]}}
